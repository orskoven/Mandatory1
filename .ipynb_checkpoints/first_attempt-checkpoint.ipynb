# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
plt.ion()

# %%
# Load the data
cars_df = pd.read_csv('cars.csv')

# %%
# Display the first few rows
print(cars_df.head())

# Get a concise summary of the DataFrame
print(cars_df.info())

# Get descriptive statistics
print(cars_df.describe())
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
# ...

# %%
# Check for missing values
print(cars_df.isnull().sum())

# Option to fill missing values
cars_df.fillna(value={'column_name': 'default_value'}, inplace=True)

# Or drop rows with missing values
cars_df.dropna(inplace=True)
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
#choose apropiate 
#linear regression 
#decision trees for non linear relationships
#evalutation metrics
#mean absolute error predicted and actual prices
#root mean square error R3 score varians
#scikit learn -> prevent

# %%
cars_df.plot()
# Out:
# <Axes: >

# %%
cars_df.plot(y=['horsepower', 'acceleration'], kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Seaborn ->  Seaborn, which is built on top of Matplotlib

# %%
import seaborn as sns
sns.set(style="whitegrid")
sns.lineplot(data=cars_df, x='weight', y='acceleration')
plt.show()

# %%
sns.set(style="whitegrid")
sns.lineplot(data=cars_df, x='model year', y='acceleration')
plt.show()

# %%
# Forumulate a problem:

# %%
#Generateing
from IPython.display import display, Math, Markdown

# %%
# Hypothesis Function
display(Markdown("###  Cars Regression Problem:"))
display(Markdown("""
1. How can we predict the parametric output value MPG (milage per gallon) using a linear regression neural network given the input parameters: ylinders  displacement horsepower  weight acceleration model year  origin car name     
"""))
# Out:
# ###  Cars Regression Problem:
# 1. How can we predict the parametric output value MPG (milage per gallon) using a linear regression neural network given the input parameters:

# %%
cars_df.head
# Out:
# <bound method NDFrame.head of       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...
